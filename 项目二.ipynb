# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

'''
Find the maximum for function: f(x) =-3*(x-30)**2*sin(x) 
'''

from math import sin, cos

from gaft import GAEngine
from gaft.components import BinaryIndividual
from gaft.components import Population
from gaft.operators import TournamentSelection
from gaft.operators import UniformCrossover
from gaft.operators import FlipBitMutation

# Analysis plugin base class.
from gaft.plugin_interfaces.analysis import OnTheFlyAnalysis

# Built-in best fitness analysis.
from gaft.analysis.fitness_store import FitnessStore

# Define population.
indv_template = BinaryIndividual(ranges=[(0, 15)], eps=0.001)
population = Population(indv_template=indv_template, size=30).init()

# Create genetic operators.
selection = TournamentSelection()
crossover = UniformCrossover(pc=0.8, pe=0.5)
mutation = FlipBitMutation(pm=0.1)

# Create genetic algorithm engine.
engine = GAEngine(population=population, selection=selection,
                  crossover=crossover, mutation=mutation,
                  analysis=[FitnessStore])

# Define fitness function.
@engine.fitness_register
def fitness(indv):
    x, = indv.solution
    return x + 10*sin(5*x) + 7*cos(4*x)

# Define on-the-fly analysis.
@engine.analysis_register
class ConsoleOutputAnalysis(OnTheFlyAnalysis):
    interval = 1
    master_only = True

    def register_step(self, g, population, engine):
        best_indv = population.best_indv(engine.fitness)
        msg = 'Generation: {}, best fitness: {:.3f}'.format(g, engine.ori_fmax)
        self.logger.info(msg)

    def finalize(self, population, engine):
        best_indv = population.best_indv(engine.fitness)
        x = best_indv.solution
        y = engine.ori_fmax
        msg = 'Optimal solution: ({}, {})'.format(x, y)
        self.logger.info(msg)

if '__main__' == __name__:
    # Run the GA engine.
    engine.run(ng=100)
# Out:
# gaft.ConsoleOutputAnalysis   INFO     Generation: 0, best fitness: 26.056
# gaft.ConsoleOutputAnalysis   INFO     Generation: 1, best fitness: 26.153
# gaft.ConsoleOutputAnalysis   INFO     Generation: 2, best fitness: 26.153
# gaft.ConsoleOutputAnalysis   INFO     Generation: 3, best fitness: 26.153
# gaft.ConsoleOutputAnalysis   INFO     Generation: 4, best fitness: 26.153
# gaft.ConsoleOutputAnalysis   INFO     Generation: 5, best fitness: 26.153
# gaft.ConsoleOutputAnalysis   INFO     Generation: 6, best fitness: 30.827
# gaft.ConsoleOutputAnalysis   INFO     Generation: 7, best fitness: 31.086
# gaft.ConsoleOutputAnalysis   INFO     Generation: 8, best fitness: 31.086
# gaft.ConsoleOutputAnalysis   INFO     Generation: 9, best fitness: 31.086
# gaft.ConsoleOutputAnalysis   INFO     Generation: 10, best fitness: 31.086
# gaft.ConsoleOutputAnalysis   INFO     Generation: 11, best fitness: 31.086
# gaft.ConsoleOutputAnalysis   INFO     Generation: 12, best fitness: 31.086
# gaft.ConsoleOutputAnalysis   INFO     Generation: 13, best fitness: 31.086
# gaft.ConsoleOutputAnalysis   INFO     Generation: 14, best fitness: 31.122
# gaft.ConsoleOutputAnalysis   INFO     Generation: 15, best fitness: 31.122
# gaft.ConsoleOutputAnalysis   INFO     Generation: 16, best fitness: 31.122
# gaft.ConsoleOutputAnalysis   INFO     Generation: 17, best fitness: 31.122
# gaft.ConsoleOutputAnalysis   INFO     Generation: 18, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 19, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 20, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 21, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 22, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 23, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 24, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 25, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 26, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 27, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 28, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 29, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 30, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 31, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 32, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 33, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 34, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 35, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 36, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 37, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 38, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 39, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 40, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 41, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 42, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 43, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 44, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 45, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 46, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 47, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 48, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 49, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 50, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 51, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 52, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 53, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 54, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 55, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 56, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 57, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 58, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 59, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 60, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 61, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 62, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 63, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 64, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 65, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 66, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 67, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 68, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 69, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 70, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 71, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 72, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 73, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 74, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 75, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 76, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 77, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 78, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 79, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 80, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 81, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 82, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 83, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 84, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 85, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 86, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 87, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 88, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 89, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 90, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 91, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 92, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 93, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 94, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 95, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 96, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 97, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 98, best fitness: 31.138
# gaft.ConsoleOutputAnalysis   INFO     Generation: 99, best fitness: 31.138
# gaft.FitnessStore   INFO     Best fitness values are written to best_fit.py
# gaft.ConsoleOutputAnalysis   INFO     Optimal solution: ([14.139404296875], 31.138498262598787)
